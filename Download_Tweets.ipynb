# %%
import tweepy #https://github.com/tweepy/tweepy
import csv
import json

# %%
#Twitter API credentials
# Put your credentials in here
consumer_key = ""
consumer_secret = ""
access_key = ""
access_secret = ""

# %%
#tweeters = ['elonmusk','NASA']

tweeters = ['elonmusk','NASA', 'nytimes','espn','katyperry','RealJamesWoods',
           'ScottAdamsSays','WilliamShatner','tim_cook','BillGates']

# %%
def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method
    
    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []    
    
    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    
    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print("getting tweets before {}".format(oldest))
        
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest,include_rts=False)
        
        #save most recent tweets
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        
        print("...{} tweets downloaded so far".format(len(alltweets)))
    
    #transform the tweepy tweets into a 2D array that will populate the csv    
    #outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode('UTF-8'),tweet.retweet_count,tweet.favorite_count] for tweet in alltweets]
    outtweets = [[tweet.text,screen_name]for tweet in alltweets]
    
    #write the csv    
    with open('{}_tweets.csv'.format(screen_name), 'w') as f:
        writer = csv.writer(f)
        #tmp = ["id","created_at","text","retweet_count","favorite_count"]
        tmp = ['text', 'author']
        #lst = [x.encode('utf-8') for x in tmp]
        writer.writerow(tmp)
        writer.writerows(outtweets)
    
    pass

# %%
for tweet in tweeters:
    get_all_tweets(tweet)
# Out:
# getting tweets before 983775391851528191
# ...383 tweets downloaded so far
# getting tweets before 966298034978959360
# ...567 tweets downloaded so far
# getting tweets before 940359019947999231
# ...743 tweets downloaded so far
# getting tweets before 908163652661927936
# ...920 tweets downloaded so far
# getting tweets before 889743207684218879
# ...1102 tweets downloaded so far
# getting tweets before 873312073756753919
# ...1284 tweets downloaded so far
# getting tweets before 862401961550692351
# ...1447 tweets downloaded so far
# getting tweets before 838558471972741119
# ...1627 tweets downloaded so far
# getting tweets before 822908233090072575
# ...1786 tweets downloaded so far
# getting tweets before 791321336824012800
# ...1934 tweets downloaded so far
# getting tweets before 763096729134575616
# ...2112 tweets downloaded so far
# getting tweets before 739631614100004863
# ...2271 tweets downloaded so far
# getting tweets before 716747672477151231
# ...
